# %%
import gymnasium as gym
import numpy as np
import random

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
eps = 500

# %%
def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(Q[state])

# %%
Q = np.zeros((48,4))

# %%
for ep in range(eps):
    if ep % 50 == 0 :
        env = gym.make("CliffWalking-v1", render_mode = "human")
    else:
        env = gym.make("CliffWalking-v1")
    done = False
    state,_ = env.reset()
    total_reward = 0
    eps_len = 0
    while not done:
        action = epsilon_greedy(state)
        next_state,reward,terminated,truncated,_ = env.step(action)
        done = terminated or truncated
        Q[state, action] += alpha * (reward + gamma * np.max(Q[next_state]) - Q[state, action])
        state = next_state
        total_reward += reward
        eps_len += 1
    print(f"episode={eps+1}/500 & total reward = {total_reward} & episode len = {eps_len}")
env.close()
# Out:
# episode=501/500 & total reward = -860 & episode len = 266
# episode=501/500 & total reward = -1173 & episode len = 381
# episode=501/500 & total reward = -286 & episode len = 187
# episode=501/500 & total reward = -176 & episode len = 77
# episode=501/500 & total reward = -199 & episode len = 100
# episode=501/500 & total reward = -42 & episode len = 42
# episode=501/500 & total reward = -75 & episode len = 75
# episode=501/500 & total reward = -158 & episode len = 59
# episode=501/500 & total reward = -39 & episode len = 39
# episode=501/500 & total reward = -54 & episode len = 54
# episode=501/500 & total reward = -64 & episode len = 64
# episode=501/500 & total reward = -35 & episode len = 35
# episode=501/500 & total reward = -58 & episode len = 58
# episode=501/500 & total reward = -176 & episode len = 77
# episode=501/500 & total reward = -58 & episode len = 58
# episode=501/500 & total reward = -131 & episode len = 32
# episode=501/500 & total reward = -36 & episode len = 36
# episode=501/500 & total reward = -29 & episode len = 29
# episode=501/500 & total reward = -56 & episode len = 56
# episode=501/500 & total reward = -50 & episode len = 50
# episode=501/500 & total reward = -142 & episode len = 43
# episode=501/500 & total reward = -28 & episode len = 28
# episode=501/500 & total reward = -27 & episode len = 27
# episode=501/500 & total reward = -41 & episode len = 41
# episode=501/500 & total reward = -32 & episode len = 32
# episode=501/500 & total reward = -35 & episode len = 35
# episode=501/500 & total reward = -133 & episode len = 34
# episode=501/500 & total reward = -22 & episode len = 22
# episode=501/500 & total reward = -29 & episode len = 29
# episode=501/500 & total reward = -27 & episode len = 27
# episode=501/500 & total reward = -135 & episode len = 36
# episode=501/500 & total reward = -24 & episode len = 24
# episode=501/500 & total reward = -22 & episode len = 22
# episode=501/500 & total reward = -22 & episode len = 22
# episode=501/500 & total reward = -30 & episode len = 30
# episode=501/500 & total reward = -31 & episode len = 31
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -28 & episode len = 28
# episode=501/500 & total reward = -26 & episode len = 26
# episode=501/500 & total reward = -20 & episode len = 20
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -33 & episode len = 33
# episode=501/500 & total reward = -134 & episode len = 35
# episode=501/500 & total reward = -23 & episode len = 23
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -25 & episode len = 25
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -18 & episode len = 18
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -26 & episode len = 26
# episode=501/500 & total reward = -18 & episode len = 18
# episode=501/500 & total reward = -24 & episode len = 24
# episode=501/500 & total reward = -352 & episode len = 55
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -237 & episode len = 39
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -117 & episode len = 18
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -117 & episode len = 18
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -126 & episode len = 27
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -18 & episode len = 18
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -137 & episode len = 38
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -18 & episode len = 18
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -122 & episode len = 23
# episode=501/500 & total reward = -122 & episode len = 23
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -21 & episode len = 21
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -21 & episode len = 21
# episode=501/500 & total reward = -225 & episode len = 27
# episode=501/500 & total reward = -114 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -23 & episode len = 23
# episode=501/500 & total reward = -216 & episode len = 18
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -223 & episode len = 25
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -116 & episode len = 17
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -327 & episode len = 30
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -126 & episode len = 27
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -118 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -115 & episode len = 16
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -223 & episode len = 25
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -235 & episode len = 37
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -223 & episode len = 25
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -24 & episode len = 24
# episode=501/500 & total reward = -116 & episode len = 17
# episode=501/500 & total reward = -119 & episode len = 20
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -118 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -21 & episode len = 21
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -129 & episode len = 30
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -226 & episode len = 28
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -21 & episode len = 21
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -244 & episode len = 46
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -21 & episode len = 21
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -113 & episode len = 14
# episode=501/500 & total reward = -234 & episode len = 36
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -128 & episode len = 29
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -221 & episode len = 23
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -20 & episode len = 20
# episode=501/500 & total reward = -221 & episode len = 23
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -231 & episode len = 33
# episode=501/500 & total reward = -119 & episode len = 20
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -115 & episode len = 16
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -26 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -20 & episode len = 20
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -231 & episode len = 33
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -116 & episode len = 17
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -229 & episode len = 31
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -122 & episode len = 23
# episode=501/500 & total reward = -223 & episode len = 25
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -441 & episode len = 45
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -213 & episode len = 15
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -126 & episode len = 27
# episode=501/500 & total reward = -122 & episode len = 23
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -117 & episode len = 18
# episode=501/500 & total reward = -333 & episode len = 36
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -237 & episode len = 39
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -341 & episode len = 44
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -22 & episode len = 22
# episode=501/500 & total reward = -126 & episode len = 27
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -230 & episode len = 32
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -113 & episode len = 14
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -132 & episode len = 33
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -114 & episode len = 15
# episode=501/500 & total reward = -336 & episode len = 39
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -235 & episode len = 37
# episode=501/500 & total reward = -237 & episode len = 39
# episode=501/500 & total reward = -23 & episode len = 23
# episode=501/500 & total reward = -222 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -126 & episode len = 27
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -122 & episode len = 23
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -127 & episode len = 28
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -115 & episode len = 16
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -124 & episode len = 25
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -120 & episode len = 21
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -120 & episode len = 21
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -220 & episode len = 22
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -540 & episode len = 45
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -123 & episode len = 24
# episode=501/500 & total reward = -24 & episode len = 24
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -227 & episode len = 29
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -118 & episode len = 19
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -227 & episode len = 29
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -120 & episode len = 21
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -113 & episode len = 14
# episode=501/500 & total reward = -118 & episode len = 19
# episode=501/500 & total reward = -18 & episode len = 18
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -659 & episode len = 65
# episode=501/500 & total reward = -120 & episode len = 21
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -115 & episode len = 16
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -116 & episode len = 17
# episode=501/500 & total reward = -125 & episode len = 26
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -19 & episode len = 19
# episode=501/500 & total reward = -116 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -16 & episode len = 16
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -229 & episode len = 31
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -228 & episode len = 30
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -121 & episode len = 22
# episode=501/500 & total reward = -20 & episode len = 20
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -20 & episode len = 20
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -117 & episode len = 18
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -233 & episode len = 35
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -119 & episode len = 20
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -120 & episode len = 21
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -115 & episode len = 16
# episode=501/500 & total reward = -119 & episode len = 20
# episode=501/500 & total reward = -226 & episode len = 28
# episode=501/500 & total reward = -225 & episode len = 27
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
# episode=501/500 & total reward = -14 & episode len = 14
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -130 & episode len = 31
# episode=501/500 & total reward = -17 & episode len = 17
# episode=501/500 & total reward = -13 & episode len = 13
# episode=501/500 & total reward = -15 & episode len = 15
